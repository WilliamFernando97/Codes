# %%
import pandas as pd

# %%
df = pd.read_csv("../Scripts/data/data_2019.csv")

# %%
df.head(3)
# Out:
#         antigüedad cuartos cuartosdebaño estacionamiento  \
# 0  En construcción       3             3               2
# 1  En construcción       4             4               0
# 2              NaN       1             1               3
#
#                                              latlong metroscuadradostotales  \
# 0  //maps.google.com/maps/api/staticmap?center=-2...                  319m²
# 1  //maps.google.com/maps/api/staticmap?center=-2...                  410m²
# 2  //maps.google.com/maps/api/staticmap?center=-2...                   83m²
#
#   precio publicado tipodevendedor  \
# 0    NaN       NaN            NaN
# 1    NaN       NaN            NaN
# 2    NaN       NaN            NaN
#
#                                               titulo
# 0                 Casa en Venta en Estancias del Rio
# 1                Isla Mocoli Urb. Pacifica - 4 Dorm.
# 2  Vendo Casa de Estreno Urbanizacion Villa Itali...

# %%
df.tail(3)
# Out:
#       antigüedad cuartos cuartosdebaño estacionamiento  \
# 10279          6       3             4               2
# 10280          1       1             2               2
# 10281         14       4             0               1
#
#                                                  latlong  \
# 10279  //maps.google.com/maps/api/staticmap?center=-2...
# 10280  //maps.google.com/maps/api/staticmap?center=nu...
# 10281  //maps.google.com/maps/api/staticmap?center=nu...
#
#       metroscuadradostotales       precio publicado tipodevendedor  \
# 10279                  350m²  USD 380.000       NaN            NaN
# 10280                  256m²  USD 220.000       NaN            NaN
# 10281                  230m²  USD 285.000       NaN            NaN
#
#                                                   titulo
# 10279  Oportunidad Moderna Casa en Via a La Costa Urb...
# 10280  Venta C Celeste Villa 1 Sola Planta 1 Dormitor...
# 10281                  Villa X Uess 4 Dormitorio Estudio

# %%
df.shape
# Out:
# (10282, 10)

# %%
df.dtypes
# Out:
# antigüedad                object
# cuartos                   object
# cuartosdebaño             object
# estacionamiento           object
# latlong                   object
# metroscuadradostotales    object
# precio                    object
# publicado                 object
# tipodevendedor            object
# titulo                    object
# dtype: object

# %%
df.drop_duplicates(subset=["titulo","latlong","metroscuadradostotales","precio"], keep="last", inplace = True)

# %%
df.shape
# Out:
# (10178, 10)

# %%
df.head(10)
# Out:
#          antigüedad cuartos cuartosdebaño estacionamiento  \
# 0   En construcción       3             3               2
# 1   En construcción       4             4               0
# 2               NaN       1             1               3
# 3                 5       3             4               2
# 4                 5       4             4               0
# 5                13       7             7              10
# 7                 4       3             4               3
# 8                 4       3             2               0
# 9               NaN       0             4              14
# 10                6       3             3               2
#
#                                               latlong metroscuadradostotales  \
# 0   //maps.google.com/maps/api/staticmap?center=-2...                  319m²
# 1   //maps.google.com/maps/api/staticmap?center=-2...                  410m²
# 2   //maps.google.com/maps/api/staticmap?center=-2...                   83m²
# ...

# %%
df.reset_index(drop=True, inplace = True)

# %%
df.head(10)
# Out:
#         antigüedad cuartos cuartosdebaño estacionamiento  \
# 0  En construcción       3             3               2
# 1  En construcción       4             4               0
# 2              NaN       1             1               3
# 3                5       3             4               2
# 4                5       4             4               0
# 5               13       7             7              10
# 6                4       3             4               3
# 7                4       3             2               0
# 8              NaN       0             4              14
# 9                6       3             3               2
#
#                                              latlong metroscuadradostotales  \
# 0  //maps.google.com/maps/api/staticmap?center=-2...                  319m²
# 1  //maps.google.com/maps/api/staticmap?center=-2...                  410m²
# 2  //maps.google.com/maps/api/staticmap?center=-2...                   83m²
# ...

# %%
df.iloc[[0,4,6],[0,-1,-2]]
# Out:
#         antigüedad                                           titulo  \
# 0  En construcción               Casa en Venta en Estancias del Rio
# 4                5  Arrecife - Punta Mocoli Design By Jannina Cabal
# 6                4           Punta Esmeralda - Casa en Venta 3d - $
#
#   tipodevendedor
# 0            NaN
# 4            NaN
# 6            NaN

# %%
df.iloc[2:10,1:3]
# Out:
#   cuartos cuartosdebaño
# 2       1             1
# 3       3             4
# 4       4             4
# 5       7             7
# 6       3             4
# 7       3             2
# 8       0             4
# 9       3             3

# %%
df.iloc[2,-1]
# Out:
# 'Vendo Casa de Estreno Urbanizacion Villa Italia, Excelente Ubicacion!'

# %%
df.head()
# Out:
#         antigüedad cuartos cuartosdebaño estacionamiento  \
# 0  En construcción       3             3               2
# 1  En construcción       4             4               0
# 2              NaN       1             1               3
# 3                5       3             4               2
# 4                5       4             4               0
#
#                                              latlong metroscuadradostotales  \
# 0  //maps.google.com/maps/api/staticmap?center=-2...                  319m²
# 1  //maps.google.com/maps/api/staticmap?center=-2...                  410m²
# 2  //maps.google.com/maps/api/staticmap?center=-2...                   83m²
# 3  //maps.google.com/maps/api/staticmap?center=-2...                  186m²
# 4  //maps.google.com/maps/api/staticmap?center=-2...                  480m²
#
#   precio publicado tipodevendedor  \
# 0    NaN       NaN            NaN
# 1    NaN       NaN            NaN
# 2    NaN       NaN            NaN
# ...

# %%
dfs = df.loc[:,["cuartos","cuartosdebaño","estacionamiento","titulo","precio"]]

# %%
dfs.head()
# Out:
#   cuartos cuartosdebaño estacionamiento  \
# 0       3             3               2
# 1       4             4               0
# 2       1             1               3
# 3       3             4               2
# 4       4             4               0
#
#                                               titulo precio
# 0                 Casa en Venta en Estancias del Rio    NaN
# 1                Isla Mocoli Urb. Pacifica - 4 Dorm.    NaN
# 2  Vendo Casa de Estreno Urbanizacion Villa Itali...    NaN
# 3  Hermosa Casa en Venta Urb. Arcadia - 3 Dorm. 2...    NaN
# 4    Arrecife - Punta Mocoli Design By Jannina Cabal    NaN

# %%
df.loc[:,"cuartos":"precio"]
# Out:
#       cuartos cuartosdebaño estacionamiento  \
# 0           3             3               2
# 1           4             4               0
# 2           1             1               3
# 3           3             4               2
# 4           4             4               0
# ...       ...           ...             ...
# 10173       4             4               2
# 10174       5             6               2
# 10175       3             4               2
# 10176       1             2               2
# 10177       4             0               1
#
#                                                  latlong  \
# 0      //maps.google.com/maps/api/staticmap?center=-2...
# 1      //maps.google.com/maps/api/staticmap?center=-2...
# 2      //maps.google.com/maps/api/staticmap?center=-2...
# 3      //maps.google.com/maps/api/staticmap?center=-2...
# 4      //maps.google.com/maps/api/staticmap?center=-2...
# ...                                                  ...
# ...

# %%
df.dtypes
# Out:
# antigüedad                object
# cuartos                   object
# cuartosdebaño             object
# estacionamiento           object
# latlong                   object
# metroscuadradostotales    object
# precio                    object
# publicado                 object
# tipodevendedor            object
# titulo                    object
# dtype: object

# %%
df = df.loc[~(df["metroscuadradostotales"] == "metroscuadradostotales")]

# %%
df.head()
# Out:
#         antigüedad cuartos cuartosdebaño estacionamiento  \
# 0  En construcción       3             3               2
# 1  En construcción       4             4               0
# 2              NaN       1             1               3
# 3                5       3             4               2
# 4                5       4             4               0
#
#                                              latlong metroscuadradostotales  \
# 0  //maps.google.com/maps/api/staticmap?center=-2...                  319m²
# 1  //maps.google.com/maps/api/staticmap?center=-2...                  410m²
# 2  //maps.google.com/maps/api/staticmap?center=-2...                   83m²
# 3  //maps.google.com/maps/api/staticmap?center=-2...                  186m²
# 4  //maps.google.com/maps/api/staticmap?center=-2...                  480m²
#
#   precio publicado tipodevendedor  \
# 0    NaN       NaN            NaN
# 1    NaN       NaN            NaN
# 2    NaN       NaN            NaN
# ...

# %%
df["metroscuadradostotales"].isnull().sum()
# Out:
# 15

# %%
df = df.loc[df["metroscuadradostotales"].notnull()]

# %%
df["metroscuadradostotales"].str.replace("m²","").astype("int64")
# Out:
# 0        319
# 1        410
# 2         83
# 3        186
# 4        480
#         ...
# 10173    660
# 10174    700
# 10175    350
# 10176    256
# 10177    230
# Name: metroscuadradostotales, Length: 10162, dtype: int64

# %%
df["metroscuadradostotales"] = df["metroscuadradostotales"].str.replace("m²","").astype("int64")

# %%
df.head()
# Out:
#         antigüedad cuartos cuartosdebaño estacionamiento  \
# 0  En construcción       3             3               2
# 1  En construcción       4             4               0
# 2              NaN       1             1               3
# 3                5       3             4               2
# 4                5       4             4               0
#
#                                              latlong  metroscuadradostotales  \
# 0  //maps.google.com/maps/api/staticmap?center=-2...                     319
# 1  //maps.google.com/maps/api/staticmap?center=-2...                     410
# 2  //maps.google.com/maps/api/staticmap?center=-2...                      83
# 3  //maps.google.com/maps/api/staticmap?center=-2...                     186
# 4  //maps.google.com/maps/api/staticmap?center=-2...                     480
#
#   precio publicado tipodevendedor  \
# 0    NaN       NaN            NaN
# 1    NaN       NaN            NaN
# 2    NaN       NaN            NaN
# ...

# %%
df.dtypes
# Out:
# antigüedad                object
# cuartos                   object
# cuartosdebaño             object
# estacionamiento           object
# latlong                   object
# metroscuadradostotales     int64
# precio                    object
# publicado                 object
# tipodevendedor            object
# titulo                    object
# dtype: object

# %%
df = df.loc[df["precio"].notnull()]

# %%
df.shape
# Out:
# (5104, 10)

# %%
df.head()
# Out:
#            antigüedad cuartos cuartosdebaño estacionamiento  \
# 5059                5       4             4               0
# 5060       A estrenar       4             3               2
# 5061               20       4             4               3
# 5062  En construcción       0             4               2
# 5063       A estrenar       4             4               0
#
#                                                 latlong  \
# 5059  //maps.google.com/maps/api/staticmap?center=-2...
# 5060  //maps.google.com/maps/api/staticmap?center=-2...
# 5061  //maps.google.com/maps/api/staticmap?center=-2...
# 5062  //maps.google.com/maps/api/staticmap?center=-2...
# 5063  //maps.google.com/maps/api/staticmap?center=-2...
#
#       metroscuadradostotales       precio publicado tipodevendedor  \
# 5059                     480  USD 565.000       NaN            NaN
# 5060                     400  USD 370.000       NaN            NaN
# ...

# %%
df = df.loc[df["precio"] != "Consultar precio"]

# %%
df["precio"] = df["precio"].str.replace("USD ","").str.replace(".","", regex = False).astype("int64")

# %%
df.head()
# Out:
#            antigüedad cuartos cuartosdebaño estacionamiento  \
# 5059                5       4             4               0
# 5060       A estrenar       4             3               2
# 5061               20       4             4               3
# 5062  En construcción       0             4               2
# 5063       A estrenar       4             4               0
#
#                                                 latlong  \
# 5059  //maps.google.com/maps/api/staticmap?center=-2...
# 5060  //maps.google.com/maps/api/staticmap?center=-2...
# 5061  //maps.google.com/maps/api/staticmap?center=-2...
# 5062  //maps.google.com/maps/api/staticmap?center=-2...
# 5063  //maps.google.com/maps/api/staticmap?center=-2...
#
#       metroscuadradostotales  precio publicado tipodevendedor  \
# 5059                     480  565000       NaN            NaN
# 5060                     400  370000       NaN            NaN
# 5061                     244  140000       NaN            NaN
# ...

# %%
df["precio"]<300000
# Out:
# 5059     False
# 5060     False
# 5061      True
# 5062      True
# 5063      True
#          ...
# 10173    False
# 10174    False
# 10175    False
# 10176     True
# 10177     True
# Name: precio, Length: 5101, dtype: bool

# %%
df["metroscuadradostotales"]>200
# Out:
# 5059      True
# 5060      True
# 5061      True
# 5062     False
# 5063      True
#          ...
# 10173     True
# 10174     True
# 10175     True
# 10176     True
# 10177     True
# Name: metroscuadradostotales, Length: 5101, dtype: bool

# %%
df.loc[(df["precio"]<300000)&(df["metroscuadradostotales"]>200)]
# Out:
#        antigüedad cuartos cuartosdebaño estacionamiento  \
# 5061           20       4             4               3
# 5063   A estrenar       4             4               0
# 5067           14       4             5               2
# 5093   A estrenar       4             4               2
# 5107           12       4             6               1
# ...           ...     ...           ...             ...
# 10167           8       3             3               1
# 10169           5       3             3               2
# 10171          25       4             4               3
# 10176           1       1             2               2
# 10177          14       4             0               1
#
#                                                  latlong  \
# 5061   //maps.google.com/maps/api/staticmap?center=-2...
# 5063   //maps.google.com/maps/api/staticmap?center=-2...
# 5067   //maps.google.com/maps/api/staticmap?center=-2...
# 5093   //maps.google.com/maps/api/staticmap?center=-2...
# ...

# %%
df.loc[df["titulo"].str.contains("urdesa", case = False)]
# Out:
#       antigüedad cuartos cuartosdebaño estacionamiento  \
# 5067          14       4             5               2
# 5157          32       4             5               0
# 5166          40       3             4               3
# 5169          20       4             4               2
# 5178           4       2             1               1
# ...          ...     ...           ...             ...
# 10080         45       4             4               2
# 10094         15       3             3               4
# 10113         49       6             5               2
# 10148         50       4             4               0
# 10171         25       4             4               3
#
#                                                  latlong  \
# 5067   //maps.google.com/maps/api/staticmap?center=-2...
# 5157   //maps.google.com/maps/api/staticmap?center=-2...
# 5166   //maps.google.com/maps/api/staticmap?center=-2...
# 5169   //maps.google.com/maps/api/staticmap?center=-2...
# ...

# %%
df.dtypes
# Out:
# antigüedad                object
# cuartos                   object
# cuartosdebaño             object
# estacionamiento           object
# latlong                   object
# metroscuadradostotales     int64
# precio                     int64
# publicado                 object
# tipodevendedor            object
# titulo                    object
# dtype: object

# %%
df.shape
# Out:
# (5101, 10)

# %%
df = df.loc[df["cuartos"].notnull()]

# %%
df.shape
# Out:
# (5057, 10)

# %%
df = df.loc[df["cuartos"].str.isdigit()]

# %%
df.shape
# Out:
# (5050, 10)

# %%
df["cuartos"] = df["cuartos"].astype("int64")

# %%
df.head()
# Out:
#            antigüedad  cuartos cuartosdebaño estacionamiento  \
# 5059                5        4             4               0
# 5060       A estrenar        4             3               2
# 5061               20        4             4               3
# 5062  En construcción        0             4               2
# 5063       A estrenar        4             4               0
#
#                                                 latlong  \
# 5059  //maps.google.com/maps/api/staticmap?center=-2...
# 5060  //maps.google.com/maps/api/staticmap?center=-2...
# 5061  //maps.google.com/maps/api/staticmap?center=-2...
# 5062  //maps.google.com/maps/api/staticmap?center=-2...
# 5063  //maps.google.com/maps/api/staticmap?center=-2...
#
#       metroscuadradostotales  precio publicado tipodevendedor  \
# 5059                     480  565000       NaN            NaN
# 5060                     400  370000       NaN            NaN
# 5061                     244  140000       NaN            NaN
# ...

# %%
df = df.reset_index(drop = True)

# %%
df.iloc[0,4]
# Out:
# '//maps.google.com/maps/api/staticmap?center=-2.115345389952465,-79.85616255437014&zoom=16&markers=-2.115345389952465,-79.85616255437014&channel=PV&size=780x456&sensor=true&scale=2&key=AIzaSyBZ0l4aIUv2yia6kSFP_hc3Q4Z_lQ0Nl5w&signature=yodWqt7SOdUVK2FNJ7YqJoJVgSw='

# %%
df[["info1","info2","info3"]] = df["latlong"].str.split(",", expand = True)

# %%
df.head()
# Out:
#         antigüedad  cuartos cuartosdebaño estacionamiento  \
# 0                5        4             4               0
# 1       A estrenar        4             3               2
# 2               20        4             4               3
# 3  En construcción        0             4               2
# 4       A estrenar        4             4               0
#
#                                              latlong  metroscuadradostotales  \
# 0  //maps.google.com/maps/api/staticmap?center=-2...                     480
# 1  //maps.google.com/maps/api/staticmap?center=-2...                     400
# 2  //maps.google.com/maps/api/staticmap?center=-2...                     244
# 3  //maps.google.com/maps/api/staticmap?center=-2...                       1
# 4  //maps.google.com/maps/api/staticmap?center=-2...                     245
#
#    precio publicado tipodevendedor  \
# 0  565000       NaN            NaN
# 1  370000       NaN            NaN
# 2  140000       NaN            NaN
# ...

# %%
df[["latitud","longitud"]] = df["latlong"].str.split("center", expand = True)[1].str.split(",",n=1,expand = True)

# %%
df.head()
# Out:
#         antigüedad  cuartos cuartosdebaño estacionamiento  \
# 0                5        4             4               0
# 1       A estrenar        4             3               2
# 2               20        4             4               3
# 3  En construcción        0             4               2
# 4       A estrenar        4             4               0
#
#                                              latlong  metroscuadradostotales  \
# 0  //maps.google.com/maps/api/staticmap?center=-2...                     480
# 1  //maps.google.com/maps/api/staticmap?center=-2...                     400
# 2  //maps.google.com/maps/api/staticmap?center=-2...                     244
# 3  //maps.google.com/maps/api/staticmap?center=-2...                       1
# 4  //maps.google.com/maps/api/staticmap?center=-2...                     245
#
#    precio publicado tipodevendedor  \
# 0  565000       NaN            NaN
# 1  370000       NaN            NaN
# 2  140000       NaN            NaN
# ...

# %%
df["latitud"] = df["latitud"].str.replace("=","")

# %%
df.head()
# Out:
#         antigüedad  cuartos cuartosdebaño estacionamiento  \
# 0                5        4             4               0
# 1       A estrenar        4             3               2
# 2               20        4             4               3
# 3  En construcción        0             4               2
# 4       A estrenar        4             4               0
#
#                                              latlong  metroscuadradostotales  \
# 0  //maps.google.com/maps/api/staticmap?center=-2...                     480
# 1  //maps.google.com/maps/api/staticmap?center=-2...                     400
# 2  //maps.google.com/maps/api/staticmap?center=-2...                     244
# 3  //maps.google.com/maps/api/staticmap?center=-2...                       1
# 4  //maps.google.com/maps/api/staticmap?center=-2...                     245
#
#    precio publicado tipodevendedor  \
# 0  565000       NaN            NaN
# 1  370000       NaN            NaN
# 2  140000       NaN            NaN
# ...

# %%
df = df.loc[df["latitud"]!="null"]

# %%
df.shape
# Out:
# (4159, 15)

# %%
df["latitud"] = df["latitud"].astype("float")

# %%
df.head()
# Out:
#         antigüedad  cuartos cuartosdebaño estacionamiento  \
# 0                5        4             4               0
# 1       A estrenar        4             3               2
# 2               20        4             4               3
# 3  En construcción        0             4               2
# 4       A estrenar        4             4               0
#
#                                              latlong  metroscuadradostotales  \
# 0  //maps.google.com/maps/api/staticmap?center=-2...                     480
# 1  //maps.google.com/maps/api/staticmap?center=-2...                     400
# 2  //maps.google.com/maps/api/staticmap?center=-2...                     244
# 3  //maps.google.com/maps/api/staticmap?center=-2...                       1
# 4  //maps.google.com/maps/api/staticmap?center=-2...                     245
#
#    precio publicado tipodevendedor  \
# 0  565000       NaN            NaN
# 1  370000       NaN            NaN
# 2  140000       NaN            NaN
# ...

# %%
df.dtypes
# Out:
# antigüedad                 object
# cuartos                     int64
# cuartosdebaño              object
# estacionamiento            object
# latlong                    object
# metroscuadradostotales      int64
# precio                      int64
# publicado                  object
# tipodevendedor             object
# titulo                     object
# info1                      object
# info2                      object
# info3                      object
# latitud                   float64
# longitud                   object
# dtype: object

# %%
df["longitud"]
# Out:
# 0       -79.85616255437014&zoom=16&markers=-2.11534538...
# 1       -79.8670732875496&zoom=16&channel=PV&size=780x...
# 2       -79.90216345507815&zoom=16&markers=-2.23032833...
# 3       -79.84206462327882&zoom=16&markers=-2.07161378...
# 4       -79.83799314794919&zoom=16&markers=-2.07941565...
#                               ...
# 5040    -78.9993077470703&zoom=16&channel=PV&size=780x...
# 5041    -79.86876096242673&zoom=16&markers=-2.14058250...
# 5042    -79.89546548465574&zoom=16&markers=-2.02878204...
# 5043    -79.90530819999998&zoom=16&channel=PV&size=780...
# 5047    -80.05308412611731&zoom=16&markers=-2.19522897...
# Name: longitud, Length: 4159, dtype: object

# %%
df["longitud"][0]
# Out:
# '-79.85616255437014&zoom=16&markers=-2.115345389952465,-79.85616255437014&channel=PV&size=780x456&sensor=true&scale=2&key=AIzaSyBZ0l4aIUv2yia6kSFP_hc3Q4Z_lQ0Nl5w&signature=yodWqt7SOdUVK2FNJ7YqJoJVgSw='

# %%
df["longitud"] = df["longitud"].str.split("&",expand=True)[0].astype("float")

# %%
df.head()
# Out:
#         antigüedad  cuartos cuartosdebaño estacionamiento  \
# 0                5        4             4               0
# 1       A estrenar        4             3               2
# 2               20        4             4               3
# 3  En construcción        0             4               2
# 4       A estrenar        4             4               0
#
#                                              latlong  metroscuadradostotales  \
# 0  //maps.google.com/maps/api/staticmap?center=-2...                     480
# 1  //maps.google.com/maps/api/staticmap?center=-2...                     400
# 2  //maps.google.com/maps/api/staticmap?center=-2...                     244
# 3  //maps.google.com/maps/api/staticmap?center=-2...                       1
# 4  //maps.google.com/maps/api/staticmap?center=-2...                     245
#
#    precio publicado tipodevendedor  \
# 0  565000       NaN            NaN
# 1  370000       NaN            NaN
# 2  140000       NaN            NaN
# ...

# %%
df.drop(columns=["latlong","publicado","tipodevendedor","info1","info2","info3"], inplace=True)

# %%
df.head()
# Out:
#         antigüedad  cuartos cuartosdebaño estacionamiento  \
# 0                5        4             4               0
# 1       A estrenar        4             3               2
# 2               20        4             4               3
# 3  En construcción        0             4               2
# 4       A estrenar        4             4               0
#
#    metroscuadradostotales  precio  \
# 0                     480  565000
# 1                     400  370000
# 2                     244  140000
# 3                       1  259000
# 4                     245  245000
#
#                                               titulo   latitud   longitud
# 0    Arrecife - Punta Mocoli Design By Jannina Cabal -2.115345 -79.856163
# 1       Vendo Casa Moderna de Estreno en Isla Mocoli -2.102443 -79.867073
# 2  Venta de Casa Cdla. del Biess Remodelada - Sec... -2.230328 -79.902163
# 3  Se Vende Proyecto en Isla Celeste Reserva Solo... -2.071614 -79.842065
# ...

# %%
df.dtypes
# Out:
# antigüedad                 object
# cuartos                     int64
# cuartosdebaño              object
# estacionamiento            object
# metroscuadradostotales      int64
# precio                      int64
# titulo                     object
# latitud                   float64
# longitud                  float64
# dtype: object

# %%
df["preciomt2"] = df["precio"]/df["metroscuadradostotales"]

# %%
df.head()
# Out:
#         antigüedad  cuartos cuartosdebaño estacionamiento  \
# 0                5        4             4               0
# 1       A estrenar        4             3               2
# 2               20        4             4               3
# 3  En construcción        0             4               2
# 4       A estrenar        4             4               0
#
#    metroscuadradostotales  precio  \
# 0                     480  565000
# 1                     400  370000
# 2                     244  140000
# 3                       1  259000
# 4                     245  245000
#
#                                               titulo   latitud   longitud  \
# 0    Arrecife - Punta Mocoli Design By Jannina Cabal -2.115345 -79.856163
# 1       Vendo Casa Moderna de Estreno en Isla Mocoli -2.102443 -79.867073
# 2  Venta de Casa Cdla. del Biess Remodelada - Sec... -2.230328 -79.902163
# 3  Se Vende Proyecto en Isla Celeste Reserva Solo... -2.071614 -79.842065
# ...

# %%
def decision(x):# es un dato
    if x == "A estrenar" or x == "En construcción" or pd.isnull(x):
        return 0
    else:
        return int(x)

# %%
df["antigüedad"] = df["antigüedad"].apply(decision)

# %%
def calculo(x):# x es una fila del dataframe
    if x["metroscuadradostotales"] !=0 and x["cuartos"] !=0:
        return [x["precio"] / x["metroscuadradostotales"],x["precio"]/x["cuartos"]]
    else:
        return [0,0]

# %%
df[["info1","info2"]] = df.apply(calculo, axis = 1, result_type = "expand")

# %%
df.head()
# Out:
#    antigüedad  cuartos cuartosdebaño estacionamiento  metroscuadradostotales  \
# 0           5        4             4               0                     480
# 1           0        4             3               2                     400
# 2          20        4             4               3                     244
# 3           0        0             4               2                       1
# 4           0        4             4               0                     245
#
#    precio                                             titulo   latitud  \
# 0  565000    Arrecife - Punta Mocoli Design By Jannina Cabal -2.115345
# 1  370000       Vendo Casa Moderna de Estreno en Isla Mocoli -2.102443
# 2  140000  Venta de Casa Cdla. del Biess Remodelada - Sec... -2.230328
# 3  259000  Se Vende Proyecto en Isla Celeste Reserva Solo... -2.071614
# 4  245000  Isla Celeste 243 m² Const y 225 m² Terreno Her... -2.079416
#
#     longitud      preciomt2        info1     info2
# ...

# %%
df.iloc[:,:-2].to_csv("../output/data_casas.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\willi\Desktop\ESPOL\Ciencia de Datos\Scripts\2-manipulación-1.ipynb Cell 73' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/willi/Desktop/ESPOL/Ciencia%20de%20Datos/Scripts/2-manipulaci%C3%B3n-1.ipynb#ch0000072?line=0'>1</a> df.iloc[:,:-2].to_csv("../output/data_casas.csv",index=False)
#
# File c:\Users\willi\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
# ...

# %%
df.head()
# Out:
#    antigüedad  cuartos cuartosdebaño estacionamiento  metroscuadradostotales  \
# 0           5        4             4               0                     480
# 1           0        4             3               2                     400
# 2          20        4             4               3                     244
# 3           0        0             4               2                       1
# 4           0        4             4               0                     245
#
#    precio                                             titulo   latitud  \
# 0  565000    Arrecife - Punta Mocoli Design By Jannina Cabal -2.115345
# 1  370000       Vendo Casa Moderna de Estreno en Isla Mocoli -2.102443
# 2  140000  Venta de Casa Cdla. del Biess Remodelada - Sec... -2.230328
# 3  259000  Se Vende Proyecto en Isla Celeste Reserva Solo... -2.071614
# 4  245000  Isla Celeste 243 m² Const y 225 m² Terreno Her... -2.079416
#
#     longitud      preciomt2        info1     info2
# ...

# %%
df["precio"].min()
# Out:
# 1

# %%
maximo = df["precio"].max()

# %%
df.loc[df["precio"]==maximo]
# Out:
#      antigüedad  cuartos cuartosdebaño estacionamiento  \
# 405           0        4             4               1
#
#      metroscuadradostotales     precio  \
# 405                     595  541925000
#
#                                                 titulo   latitud   longitud  \
# 405  Casa por Construir en Venta 285 m² - Aires del... -2.271652 -78.999308
#
#          preciomt2          info1        info2
# 405  910798.319328  910798.319328  135481250.0

# %%
df["precio"].mean()
# Out:
# 463127.4914642943

# %%
df["precio"].median()
# Out:
# 228000.0

# %%
df["precio"].std()
# Out:
# 8531334.353637962

# %%
df.head()
# Out:
#    antigüedad  cuartos cuartosdebaño estacionamiento  metroscuadradostotales  \
# 0           5        4             4               0                     480
# 1           0        4             3               2                     400
# 2          20        4             4               3                     244
# 3           0        0             4               2                       1
# 4           0        4             4               0                     245
#
#    precio                                             titulo   latitud  \
# 0  565000    Arrecife - Punta Mocoli Design By Jannina Cabal -2.115345
# 1  370000       Vendo Casa Moderna de Estreno en Isla Mocoli -2.102443
# 2  140000  Venta de Casa Cdla. del Biess Remodelada - Sec... -2.230328
# 3  259000  Se Vende Proyecto en Isla Celeste Reserva Solo... -2.071614
# 4  245000  Isla Celeste 243 m² Const y 225 m² Terreno Her... -2.079416
#
#     longitud      preciomt2        info1     info2
# ...

# %%
df.describe()
# Out:
#         antigüedad      cuartos  metroscuadradostotales        precio  \
# count  4159.000000  4159.000000             4159.000000  4.159000e+03
# mean      8.439529     3.440971              603.286848  4.631275e+05
# std      10.004575     1.860662            11103.991517  8.531334e+06
# min      -2.000000     0.000000                0.000000  1.000000e+00
# 25%       0.000000     3.000000              160.000000  1.180000e+05
# 50%       5.000000     3.000000              258.000000  2.280000e+05
# 75%      12.000000     4.000000              467.500000  4.000000e+05
# max     186.000000    45.000000           700000.000000  5.419250e+08
#
#            latitud     longitud    preciomt2          info1         info2
# count  4046.000000  4046.000000  4159.000000    4159.000000  4.159000e+03
# mean     -2.117768   -79.896776          inf    1254.074935  1.153205e+05
# std       0.813582     0.485212          NaN   16405.399169  2.101802e+06
# ...

# %%
df = df.loc[df["metroscuadradostotales"]>0]

# %%
df.head()
# Out:
#    antigüedad  cuartos cuartosdebaño estacionamiento  metroscuadradostotales  \
# 0           5        4             4               0                     480
# 1           0        4             3               2                     400
# 2          20        4             4               3                     244
# 3           0        0             4               2                       1
# 4           0        4             4               0                     245
#
#    precio                                             titulo   latitud  \
# 0  565000    Arrecife - Punta Mocoli Design By Jannina Cabal -2.115345
# 1  370000       Vendo Casa Moderna de Estreno en Isla Mocoli -2.102443
# 2  140000  Venta de Casa Cdla. del Biess Remodelada - Sec... -2.230328
# 3  259000  Se Vende Proyecto en Isla Celeste Reserva Solo... -2.071614
# 4  245000  Isla Celeste 243 m² Const y 225 m² Terreno Her... -2.079416
#
#     longitud      preciomt2        info1     info2
# ...

# %%
df.describe()
# Out:
#         antigüedad      cuartos  metroscuadradostotales        precio  \
# count  4156.000000  4156.000000             4156.000000  4.156000e+03
# mean      8.445621     3.424687              603.722329  4.633179e+05
# std      10.005615     1.744817            11107.987618  8.534410e+06
# min      -2.000000     0.000000                1.000000  1.000000e+00
# 25%       0.000000     3.000000              160.000000  1.180000e+05
# 50%       5.000000     3.000000              258.500000  2.280000e+05
# 75%      12.000000     4.000000              468.500000  4.000000e+05
# max     186.000000    45.000000           700000.000000  5.419250e+08
#
#            latitud     longitud      preciomt2          info1         info2
# count  4043.000000  4043.000000    4156.000000    4156.000000  4.156000e+03
# mean     -2.117731   -79.896773    1510.194043    1254.980187  1.154037e+05
# std       0.813882     0.485391   18996.676116   16411.286006  2.102558e+06
# ...

# %%
q1 = df["precio"].quantile(0.25)

# %%
q1
# Out:
# 118000.0

# %%
d1 = df["precio"].quantile(0.1)

# %%
d1
# Out:
# 75000.0

# %%
df.loc[df.isna().any(axis = 1)]
# Out:
#       antigüedad  cuartos cuartosdebaño estacionamiento  \
# 184            0        1             1               3
# 196           10        4             3               2
# 199            4        3             3               4
# 221            9        3             4               2
# 282            5        3             4               2
# ...          ...      ...           ...             ...
# 4511          10        3             4               2
# 4520           5        4             5               4
# 4562           1        4             4               2
# 4658           8        4             5               2
# 4824           4        3             3               2
#
#       metroscuadradostotales  precio  \
# 184                      282  140000
# 196                      410  440000
# 199                     1800  580000
# 221                      515  445000
# 282                      273  330000
# ...                      ...     ...
# ...

# %%
df.isna().any(axis = 1).sum()
# Out:
# 113

# %%
ser = df.isna().sum(axis = 1)

# %%
ser[ser>0]
# Out:
# 184     2
# 196     2
# 199     2
# 221     2
# 282     2
#        ..
# 4511    2
# 4520    2
# 4562    2
# 4658    2
# 4824    2
# Length: 113, dtype: int64

# %%
df.dropna(subset=["latitud","longitud"],inplace = True)

# %%
df.shape
# Out:
# (4043, 12)

# %%
df.head()
# Out:
#    antigüedad  cuartos cuartosdebaño estacionamiento  metroscuadradostotales  \
# 0           5        4             4               0                     480
# 1           0        4             3               2                     400
# 2          20        4             4               3                     244
# 3           0        0             4               2                       1
# 4           0        4             4               0                     245
#
#    precio                                             titulo   latitud  \
# 0  565000    Arrecife - Punta Mocoli Design By Jannina Cabal -2.115345
# 1  370000       Vendo Casa Moderna de Estreno en Isla Mocoli -2.102443
# 2  140000  Venta de Casa Cdla. del Biess Remodelada - Sec... -2.230328
# 3  259000  Se Vende Proyecto en Isla Celeste Reserva Solo... -2.071614
# 4  245000  Isla Celeste 243 m² Const y 225 m² Terreno Her... -2.079416
#
#     longitud      preciomt2        info1     info2
# ...

# %%
df["cuartosdebaño"].unique()
# Out:
# array(['4', '3', '5', '2', '6', '1', '7', '11', '0', '8', '9', '10', '19',
#        '13', '18', '12', '14', '15'], dtype=object)

# %%
df["cuartosdebaño"].nunique()
# Out:
# 18

# %%
df["cuartosdebaño"].value_counts().sort_values(ascending = False)
# Out:
# 3     1266
# 4     1043
# 2      692
# 5      355
# 0      192
# 1      184
# 6      164
# 7       74
# 8       38
# 9       15
# 10       9
# 11       3
# 13       2
# 15       2
# 19       1
# 18       1
# 12       1
# 14       1
# Name: cuartosdebaño, dtype: int64

# %%
df.head()
# Out:
#    antigüedad  cuartos cuartosdebaño estacionamiento  metroscuadradostotales  \
# 0           5        4             4               0                     480
# 1           0        4             3               2                     400
# 2          20        4             4               3                     244
# 3           0        0             4               2                       1
# 4           0        4             4               0                     245
#
#    precio                                             titulo   latitud  \
# 0  565000    Arrecife - Punta Mocoli Design By Jannina Cabal -2.115345
# 1  370000       Vendo Casa Moderna de Estreno en Isla Mocoli -2.102443
# 2  140000  Venta de Casa Cdla. del Biess Remodelada - Sec... -2.230328
# 3  259000  Se Vende Proyecto en Isla Celeste Reserva Solo... -2.071614
# 4  245000  Isla Celeste 243 m² Const y 225 m² Terreno Her... -2.079416
#
#     longitud      preciomt2        info1     info2
# ...

# %%
df.sort_values(by=["precio","metroscuadradostotales"], ascending = False)
# Out:
#       antigüedad  cuartos cuartosdebaño estacionamiento  \
# 405            0        4             4               1
# 643            0        0             0               3
# 4724           8        6             7               6
# 3571           5        4             4               2
# 3837           0        4             4               2
# ...          ...      ...           ...             ...
# 2422           6        3             2               1
# 4273           9        3             2               1
# 3691           1        2             2               3
# 2879           2        3             2               1
# 845           10        0             6               4
#
#       metroscuadradostotales     precio  \
# 405                      595  541925000
# 643                      169   95000160
# 4724                    6000    6000000
# 3571                     375    4880000
# 3837                     920    4400000
# ...                      ...        ...
# ...
